# %%
import pandas as pd

df_2015 = pd.read_csv("../raw_data/flights_2015.csv")
df_2016 = pd.read_csv("../raw_data/flights_2016.csv")

print("2015 Shape:", df_2015.shape)
print("2016 Shape:", df_2016.shape)

df_2015.head()
